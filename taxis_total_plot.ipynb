# %%
import seaborn as sns
import matplotlib as plt
import pandas as pd

# %%
df_taxis = sns.load_dataset("taxis")

# %%
df_taxis["total"].describe()
# Out:
# count    6433.000000
# mean       18.517794
# std        13.815570
# min         1.300000
# 25%        10.800000
# 50%        14.160000
# 75%        20.300000
# max       174.820000
# Name: total, dtype: float64

# %%
df_taxis.to_csv(r"C:\Users\User\Documents\GitHub\Tagesaufgabe3_020823\taxis.csv")

# %%
sns.boxplot(data=df_taxis, y="total")
# Out:
# <Axes: ylabel='total'>
